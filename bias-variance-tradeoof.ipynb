# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
# Simulate data
np.random.seed(0)
X = np.sort(np.random.rand(80) * 5)
y = np.sin(X) + np.random.randn(80) * 0.2

# Try different polynomial degrees
degrees = [1, 3, 10]
X = X.reshape(-1, 1)
plt.figure(figsize=(10, 5))
for deg in degrees:
    poly = PolynomialFeatures(degree=deg)
    X_poly = poly.fit_transform(X)
    model = LinearRegression().fit(X_poly, y)
    y_pred = model.predict(X_poly)
    plt.plot(X, y_pred, label=f'Degree {deg}')

plt.scatter(X, y, color='black', label='Data')
plt.legend()
plt.title("Bias-Variance Tradeoff Example")
plt.show()

# %%
X = np.sort(np.random.rand(80))

# %%
X.shape
# Out:
# (80,)

# %%
X
# Out:
# array([0.00270321, 0.0078841 , 0.01687167, 0.0243132 , 0.03023526,
#        0.03603382, 0.0486903 , 0.07648677, 0.08949455, 0.09088573,
#        0.09724293, 0.10462789, 0.11570323, 0.13346147, 0.16023047,
#        0.16046764, 0.174772  , 0.20492369, 0.20974995, 0.2277595 ,
#        0.25364252, 0.27906795, 0.28269965, 0.30002892, 0.33350747,
#        0.33396487, 0.34169811, 0.34261098, 0.34847599, 0.37267907,
#        0.38913468, 0.40594232, 0.41030156, 0.44026375, 0.44203564,
#        0.44613551, 0.44639442, 0.50272076, 0.5098072 , 0.51995237,
#        0.53053721, 0.54138079, 0.54367805, 0.57714024, 0.58873961,
#        0.60039224, 0.61882617, 0.62223106, 0.62238443, 0.62329467,
#        0.64719665, 0.66111751, 0.67195714, 0.67624248, 0.68051448,
#        0.69395641, 0.69527001, 0.69648243, 0.71033683, 0.7105284 ,
#        0.74009753, 0.79084016, 0.81367865, 0.82989737, 0.86231855,
#        0.87178573, 0.87923476, 0.88630467, 0.88696078, 0.90787559,
#        0.91978281, 0.92211146, 0.92234798, 0.92330607, 0.92415877,
#        0.94886102, 0.9521427 , 0.96277032, 0.96828641, 0.98058013])

# %%
y = np.sin(X) + np.random.randn(80) * 0.2

# %%
y
# Out:
# array([-0.20822248,  0.17193359,  0.10949694,  0.08012996,  0.09801148,
#         0.44023473, -0.04510178, -0.36387604,  0.12923517,  0.08063995,
#        -0.00641407, -0.09132887,  0.02760734,  0.16933331,  0.05898238,
#         0.6422706 , -0.01821726,  0.04486897, -0.24950867,  0.27609234,
#        -0.15234973,  0.16756885,  0.22381505,  0.15360224,  0.67513378,
#         0.52667028,  0.59891489,  0.15946371,  0.56718461,  0.46331209,
#         0.53366912,  0.60077244,  0.21713323,  0.34131456,  0.60029953,
#        -0.09964129,  0.73438169,  0.59243787,  0.47886818,  0.54094034,
#         0.30000972,  0.44533115,  0.73734407,  0.80523401,  1.09455808,
#         0.55018122,  0.44836881,  0.48000273,  0.37936577,  0.56814251,
#         0.67949882,  0.60715084,  0.84178822,  0.57902369,  0.55970286,
#         0.52332986,  0.31406589,  0.32796978,  0.41625759,  0.91252001,
#         0.85341198,  0.98593718,  0.46037636,  0.34413717,  0.62734197,
#         0.800643  ,  0.86998914,  0.98433499,  0.83201117,  1.13673187,
#         0.75094889,  0.61426317,  0.46077824,  0.61980588,  0.84653779,
#         0.6350084 ,  1.0020085 ,  1.1032428 ,  0.34999843,  1.00363084])
